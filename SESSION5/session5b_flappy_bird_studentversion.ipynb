# %% [markdown]
# # RL Bootcamp (S5): Flappy Bird
#
# Goal: to build an environment for Flappy Bird game, train and evaluate the Reinforcement Learning agent using DQN algorithm, using StableBaseline library.
#
# Flappy Bird is a simple game where you tap the screen to make the bird fly upward. The bird falls down if you don’t tap. You must avoid hitting pipes and try to pass through the gaps. Each time you pass a pipe, you get a point. The goal is to get the highest score without crashing.
#
# ![Screenshot 2026-04-10 at 4.07.34 AM.png](data:image/png;base64,...)

# %% [markdown]
# States:
# the last pipe's horizontal position
# the last top pipe's vertical position
# the last bottom pipe's vertical position
# the next pipe's horizontal position
# the next top pipe's vertical position
# the next bottom pipe's vertical position
# the next next pipe's horizontal position
# the next next top pipe's vertical position
# the next next bottom pipe's vertical position
# player's vertical position
# player's vertical velocity
# player's rotation
#
# Actions:
# 0 - do nothing
# 1 - flap
#
# Rewards
# +0.1 - every frame it stays alive
# +1.0 - successfully passing a pipe
# -1.0 - dying
# −0.5 - touch the top of the screen

# %% [markdown]
# # Library Installation and Initialize Parameters

# %%
# %pip install -q gymnasium stable-baselines3 matplotlib
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.5/187.5 kB 4.6 MB/s eta 0:00:00

# %%
import os
from pathlib import Path
from typing import Any, Dict, List, Optional, Tuple, Union
from enum import IntEnum
from itertools import cycle

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

import pygame
from pygame import Rect
from pygame import image as pyg_image
from pygame.transform import flip as img_flip

import gymnasium
import imageio

from IPython.display import Image, display

from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy

SEED = 7
np.random.seed(SEED)
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
# SET UP CONSTANTS
PIPE_VEL_X = -4
PLAYER_MAX_VEL_Y = 10  # max vel along Y, max descend speed
PLAYER_MIN_VEL_Y = -8  # min vel along Y, max ascend speed
PLAYER_ACC_Y = 1  # players downward acceleration
PLAYER_VEL_ROT = 3  # angular speed
PLAYER_FLAP_ACC = -9  # players speed on flapping
PLAYER_WIDTH = 34
PLAYER_HEIGHT = 24
PLAYER_PRIVATE_ZONE = (max(PLAYER_WIDTH, PLAYER_HEIGHT) + 30) / 2
LIDAR_MAX_DISTANCE = int(288 * 0.8) - PLAYER_WIDTH
PIPE_WIDTH = 52
PIPE_HEIGHT = 320
BASE_WIDTH = 336
BASE_HEIGHT = 112
BACKGROUND_WIDTH = 288
BACKGROUND_HEIGHT = 512
PLAYER_ROT_THR = 20 #: Player's rotation threshold.
FILL_BACKGROUND_COLOR = (200, 200, 200) #: Color to fill the surface's background when no background image was loaded.

# %% [markdown]
# Download Image Access: https://drive.google.com/file/d/1waxu759EIPvJG0AIMtRpgO3Uy8OrLIT7/view?usp=sharing.
#
# Place zip file in the content folder in this notebook.
#
# Run the code below to extract images.

# %%
# !unzip /content/sprites.zip -d /content/
# Out:
# Archive:  /content/sprites.zip
#    creating: /content/sprites/
#   inflating: /content/__MACOSX/._sprites
#   inflating: /content/sprites/redbird-downflap.png
#   inflating: /content/__MACOSX/sprites/._redbird-downflap.png
#   inflating: /content/sprites/pipe-red.png
#   inflating: /content/__MACOSX/sprites/._pipe-red.png
#   inflating: /content/sprites/background-day.png
#   inflating: /content/__MACOSX/sprites/._background-day.png
#   inflating: /content/sprites/8.png
#   inflating: /content/__MACOSX/sprites/._8.png
#   inflating: /content/sprites/redbird-midflap.png
#   inflating: /content/__MACOSX/sprites/._redbird-midflap.png
#   inflating: /content/sprites/bluebird-midflap.png
#   inflating: /content/__MACOSX/sprites/._bluebird-midflap.png
#   inflating: /content/sprites/9.png
#   inflating: /content/__MACOSX/sprites/._9.png
#   inflating: /content/sprites/yellowbird-upflap.png
#   inflating: /content/__MACOSX/sprites/._yellowbird-upflap.png
#   inflating: /content/sprites/bluebird-upflap.png
#   inflating: /content/__MACOSX/sprites/._bluebird-upflap.png
#   inflating: /content/sprites/background-night.png
#   inflating: /content/__MACOSX/sprites/._background-night.png
#   inflating: /content/sprites/redbird-upflap.png
#   inflating: /content/__MACOSX/sprites/._redbird-upflap.png
#   inflating: /content/sprites/yellowbird-midflap.png
#   inflating: /content/__MACOSX/sprites/._yellowbird-midflap.png
#   inflating: /content/sprites/yellowbird-downflap.png
#   inflating: /content/__MACOSX/sprites/._yellowbird-downflap.png
#   inflating: /content/sprites/pipe-green.png
#   inflating: /content/__MACOSX/sprites/._pipe-green.png
#   inflating: /content/sprites/bluebird-downflap.png
#   inflating: /content/__MACOSX/sprites/._bluebird-downflap.png
#   inflating: /content/sprites/base.png
#   inflating: /content/__MACOSX/sprites/._base.png
#   inflating: /content/sprites/gameover.png
#   inflating: /content/__MACOSX/sprites/._gameover.png
#   inflating: /content/sprites/4.png
#   inflating: /content/__MACOSX/sprites/._4.png
#   inflating: /content/sprites/5.png
#   inflating: /content/__MACOSX/sprites/._5.png
#   inflating: /content/sprites/7.png
#   inflating: /content/__MACOSX/sprites/._7.png
#   inflating: /content/sprites/6.png
#   inflating: /content/__MACOSX/sprites/._6.png
#   inflating: /content/sprites/2.png
#   inflating: /content/__MACOSX/sprites/._2.png
#   inflating: /content/sprites/message.png
#   inflating: /content/__MACOSX/sprites/._message.png
#   inflating: /content/sprites/3.png
#   inflating: /content/__MACOSX/sprites/._3.png
#   inflating: /content/sprites/1.png
#   inflating: /content/__MACOSX/sprites/._1.png
#   inflating: /content/sprites/0.png
#   inflating: /content/__MACOSX/sprites/._0.png

# %% [markdown]
# Run below scripts to set up visualization scripts

# %%
SPRITES_PATH = "sprites"


def pixel_collision(
    rect1: Rect, rect2: Rect, hitmask1: List[List[bool]], hitmask2: List[List[bool]]
) -> bool:
    """Checks if two objects collide and not just their rects."""
    rect = rect1.clip(rect2)

    if rect.width == 0 or rect.height == 0:
        return False

    x1, y1 = rect.x - rect1.x, rect.y - rect1.y
    x2, y2 = rect.x - rect2.x, rect.y - rect2.y

    for x in range(rect.width):
        for y in range(rect.height):
            if hitmask1[x1 + x][y1 + y] and hitmask2[x2 + x][y2 + y]:
                return True
    return False


def get_hitmask(image) -> List[List[bool]]:
    """Returns a hitmask using an image's alpha."""
    mask = []
    for x in range(image.get_width()):
        mask.append([])
        for y in range(image.get_height()):
            mask[x].append(bool(image.get_at((x, y))[3]))
    return mask


def _load_sprite(filename: str, convert: bool, alpha: bool = True):
    img_path = Path(SPRITES_PATH) / filename
    img = pyg_image.load(str(img_path))
    return (
        img.convert_alpha() if convert and alpha else img.convert() if convert else img
    )


def load_images(
    convert: bool = False,
    bg_type: Optional[str] = "day",
    bird_color: str = "yellow",
    pipe_color: str = "green",
) -> Dict[str, Any]:
    """Loads and returns the image assets of the game."""
    images = {}

    try:
        images["numbers"] = tuple(
            _load_sprite(f"{n}.png", convert=convert, alpha=True) for n in range(10)
        )

        images["gameover"] = _load_sprite("gameover.png", convert=convert, alpha=True)
        images["message"] = _load_sprite("message.png", convert=convert, alpha=True)
        images["base"] = _load_sprite("base.png", convert=convert, alpha=True)

        if bg_type is None:
            images["background"] = None
        else:
            images["background"] = _load_sprite(
                f"background-{bg_type}.png", convert=convert, alpha=False
            )

        images["player"] = (
            _load_sprite(f"{bird_color}bird-upflap.png", convert=convert, alpha=True),
            _load_sprite(f"{bird_color}bird-midflap.png", convert=convert, alpha=True),
            _load_sprite(f"{bird_color}bird-downflap.png", convert=convert, alpha=True),
        )

        pipe_sprite = _load_sprite(
            f"pipe-{pipe_color}.png", convert=convert, alpha=True
        )
        images["pipe"] = (img_flip(pipe_sprite, False, True), pipe_sprite)

    except FileNotFoundError as ex:
        raise FileNotFoundError(
            f"Can't find sprite files in: {SPRITES_PATH}\n"
        ) from ex

    return images

# %% [markdown]
# # Build a Flappy Bird Environment

# %%
class Actions(IntEnum):
    """Possible actions for the player to take."""

    IDLE, FLAP = 0, 1


class FlappyBirdEnv(gymnasium.Env):
    metadata = {"render_modes": ["human", "rgb_array"], "render_fps": 30}

    def __init__(
        self,
        render_mode: Optional[str] = None,
        score_limit: Optional[int] = None,
    ) -> None:
        self.action_space = gymnasium.spaces.Discrete(1) # MODIFY THIS
        self.observation_space = gymnasium.spaces.Box( # MODIFY THIS
            -np.inf, np.inf, shape=(1,), dtype=np.float64
        )
        self._set_flappy_bird_configuration(render_mode, score_limit)

    def reset(self, seed=None, options=None):
        """Resets the environment (starts a new game)."""
        super().reset(seed=seed)
        self._reset_environment_configuration()
# Agent Observe the environment
        obs, _ = np.array([0]), None #MODIFY THIS
        # Return a 12 observations of the states
            # the last pipe's horizontal position
            # the last top pipe's vertical position
            # the last bottom pipe's vertical position
            # the next pipe's horizontal position
            # the next top pipe's vertical position
            # the next bottom pipe's vertical position
            # the next next pipe's horizontal position
            # the next next top pipe's vertical position
            # the next next bottom pipe's vertical position
            # player's vertical position
            # player's vertical velocity
            # player's rotation
        # Example: Obs: [ 92. 160. 260. 236. 160. 260. 288.   0. 512. -75.   4.   6.]

        info = {"score": self._score}
        return obs, info


    def step(
        self,
        action: Union[Actions, int],
    ) -> Tuple[np.ndarray, float, bool, Dict]:

        terminal = False
        reward = None
# Agent Do an Action
        if action == Actions.FLAP:
            if self._player_y > -2 * PLAYER_HEIGHT:
                self._player_vel_y = PLAYER_FLAP_ACC
                self._player_flapped = True

# Agent Pass a Pipe
        # check for score
        player_mid_pos = self._player_x + PLAYER_WIDTH / 2
        for pipe in self._upper_pipes:
            pipe_mid_pos = pipe["x"] + PIPE_WIDTH / 2
            if pipe_mid_pos <= player_mid_pos < pipe_mid_pos + 4:
                self._score += 1
                # Reward for passing a pipe
                reward = 0

# State Transition Function (Player Change Position)
        # player_index base_x change
        if (self._loop_iter + 1) % 3 == 0:
            self._player_idx = next(self._player_idx_gen)

        self._loop_iter = (self._loop_iter + 1) % 30
        self._ground["x"] = -((-self._ground["x"] + 100) % self._base_shift)

        # rotate the player
        if self._player_rot > -90:
            self._player_rot -= PLAYER_VEL_ROT

        # player's movement
        if self._player_vel_y < PLAYER_MAX_VEL_Y and not self._player_flapped:
            self._player_vel_y += PLAYER_ACC_Y

        if self._player_flapped:
            self._player_flapped = False

            # more rotation to cover the threshold
            # (calculated in visible rotation)
            self._player_rot = 45

        self._player_y += min(
            self._player_vel_y, self._ground["y"] - self._player_y - PLAYER_HEIGHT
        )
# State Transition Function (The Pipes Move)
        # move pipes to left
        for up_pipe, low_pipe in zip(self._upper_pipes, self._lower_pipes):
            up_pipe["x"] += PIPE_VEL_X
            low_pipe["x"] += PIPE_VEL_X

            # it is out of the screen
            if up_pipe["x"] < -PIPE_WIDTH:
                new_up_pipe, new_low_pipe = self._get_random_pipe()
                up_pipe["x"] = new_up_pipe["x"]
                up_pipe["y"] = new_up_pipe["y"]
                low_pipe["x"] = new_low_pipe["x"]
                low_pipe["y"] = new_low_pipe["y"]

# Get New Observation
        obs, _ = np.array([0]), None #MODIFY THIS
        if reward is None:
            # MODIFY THIS
            reward = 0  # reward for staying alive


        # agent touch the top of the screen as punishment
        if self._player_y < 0:
          # MODIFY THIS
            reward = 0

        # check for crash
        if self._check_crash():
            # MODIFY THIS
            reward = 0  # reward for dying
            terminal = True
            self._player_vel_y = 0

        info = {"score": self._score}

        return (
            obs,
            reward,
            terminal,
            (self._score_limit is not None) and (self._score >= self._score_limit),
            info,
        )

    def render(self) -> None:
        """Renders the next frame."""
        if self.render_mode == "rgb_array":
            self._draw_surface(show_score=True)
            # Flip the image to retrieve a correct aspect
            return np.transpose(pygame.surfarray.array3d(self._surface), axes=(1, 0, 2))
        else:
            self._draw_surface(show_score=True)
            if self._display is None:
                self._make_display()

            self._update_display()
            self._fps_clock.tick(self.metadata["render_fps"])

    def close(self):
        """Closes the environment."""
        if self.render_mode is not None:
            pygame.display.quit()
            pygame.quit()
        super().close()

    def _reset_environment_configuration(self) -> None:
        """Reset player state, respawn pipes, and draw first frame in human mode."""
        self._player_x = int(self._screen_width * 0.2)
        self._player_y = int((self._screen_height - PLAYER_HEIGHT) / 2)
        self._player_vel_y = -9  # player"s velocity along Y
        self._player_rot = 45  # player"s rotation
        self._player_idx = 0
        self._loop_iter = 0
        self._score = 0

        new_pipe1 = self._get_random_pipe()
        new_pipe2 = self._get_random_pipe()
        new_pipe3 = self._get_random_pipe()

        self._upper_pipes = [
            {"x": self._screen_width, "y": new_pipe1[0]["y"]},
            {
                "x": self._screen_width + (self._screen_width / 2),
                "y": new_pipe2[0]["y"],
            },
            {
                "x": self._screen_width + self._screen_width,
                "y": new_pipe3[0]["y"],
            },
        ]

        self._lower_pipes = [
            {"x": self._screen_width, "y": new_pipe1[1]["y"]},
            {
                "x": self._screen_width + (self._screen_width / 2),
                "y": new_pipe2[1]["y"],
            },
            {
                "x": self._screen_width + self._screen_width,
                "y": new_pipe3[1]["y"],
            },
        ]

    def _set_flappy_bird_configuration(
        self,
        render_mode: Optional[str],
        score_limit: Optional[int],
        ) -> None:
        """Apply fixed game/render settings (resolution, assets, ground, pygame)."""
        assert render_mode is None or render_mode in self.metadata["render_modes"]
        self.render_mode = render_mode
        self._score_limit = score_limit
        self._screen_width = 288
        self._screen_height = 512
        self._pipe_gap = 100
        self._sound_cache = None
        self._player_flapped = False
        self._player_idx_gen = cycle([0, 1, 2, 1])
        self._bird_color = "yellow"
        self._pipe_color = "green"
        self._bg_type = "day"

        self._ground = {"x": 0, "y": self._screen_height * 0.79}
        self._base_shift = BASE_WIDTH - BACKGROUND_WIDTH

        if render_mode is not None:
            self._fps_clock = pygame.time.Clock()
            self._display = None
            self._surface = pygame.Surface((288, 512))
            self._images = load_images(
                convert=False,
                bird_color="yellow",
                pipe_color="green",
                bg_type="day",
            )

    def _get_random_pipe(self) -> Dict[str, int]:
        """Returns a randomly generated pipe."""
        # y of gap between upper and lower pipe
        gapYs = [20, 30, 40, 50, 60, 70, 80, 90]
        index = self.np_random.integers(0, len(gapYs))
        gap_y = gapYs[index]
        gap_y += int(self._ground["y"] * 0.2)

        pipe_x = self._screen_width + PIPE_WIDTH + (self._screen_width * 0.2)
        return [
            {"x": pipe_x, "y": gap_y - PIPE_HEIGHT},  # upper pipe
            {"x": pipe_x, "y": gap_y + self._pipe_gap},  # lower pipe
        ]

    def _check_crash(self) -> bool:
        """Returns True if player collides with the ground (base) or a pipe."""
        # if player crashes into ground
        if self._player_y + PLAYER_HEIGHT >= self._ground["y"] - 1:
            return True
        else:
            player_rect = pygame.Rect(
                self._player_x, self._player_y, PLAYER_WIDTH, PLAYER_HEIGHT
            )

            for up_pipe, low_pipe in zip(self._upper_pipes, self._lower_pipes):
                # upper and lower pipe rects
                up_pipe_rect = pygame.Rect(
                    up_pipe["x"], up_pipe["y"], PIPE_WIDTH, PIPE_HEIGHT
                )
                low_pipe_rect = pygame.Rect(
                    low_pipe["x"], low_pipe["y"], PIPE_WIDTH, PIPE_HEIGHT
                )

                # check collision
                up_collide = player_rect.colliderect(up_pipe_rect)
                low_collide = player_rect.colliderect(low_pipe_rect)

                if up_collide or low_collide:
                    return True

        return False

    def _get_observation(self):
        """12D raw feature observation; second value is unused (no lidar bonus)."""
        pipes = []
        for up_pipe, low_pipe in zip(self._upper_pipes, self._lower_pipes):
            # the pipe is behind the screen?
            if low_pipe["x"] > self._screen_width:
                pipes.append((self._screen_width, 0, self._screen_height))
            else:
                pipes.append(
                    (low_pipe["x"], (up_pipe["y"] + PIPE_HEIGHT), low_pipe["y"])
                )

        pipes = sorted(pipes, key=lambda x: x[0])
        pos_y = self._player_y
        vel_y = self._player_vel_y
        rot = self._player_rot

        return (
            np.array(
                [
                    pipes[0][0],
                    pipes[0][1],
                    pipes[0][2],
                    pipes[1][0],
                    pipes[1][1],
                    pipes[1][2],
                    pipes[2][0],
                    pipes[2][1],
                    pipes[2][2],
                    pos_y,
                    vel_y,
                    rot,
                ],
                dtype=np.float64,
            ),
            None,
        )

    def _make_display(self) -> None:
        """Initializes the pygame's display.

        Required for drawing images on the screen.
        """
        self._display = pygame.display.set_mode(
            (self._screen_width, self._screen_height)
        )
        for name, value in self._images.items():
            if value is None:
                continue

            if type(value) in (tuple, list):
                self._images[name] = tuple([img.convert_alpha() for img in value])
            else:
                self._images[name] = (
                    value.convert() if name == "background" else value.convert_alpha()
                )

    def _draw_score(self) -> None:
        """Draws the score in the center of the surface."""
        score_digits = [int(x) for x in list(str(self._score))]
        total_width = 0  # total width of all numbers to be printed

        for digit in score_digits:
            total_width += self._images["numbers"][digit].get_width()

        x_offset = (self._screen_width - total_width) / 2

        for digit in score_digits:
            self._surface.blit(
                self._images["numbers"][digit], (x_offset, self._screen_height * 0.1)
            )
            x_offset += self._images["numbers"][digit].get_width()

    def _draw_surface(self, show_score: bool = True) -> None:
        """Re-draws the renderer's surface.

        This method updates the renderer's surface by re-drawing it according to
        the current state of the game.

        Args:
            show_score (bool): Whether to draw the player's score or not.
        """
        # Background
        if self._images["background"] is not None:
            self._surface.blit(self._images["background"], (0, 0))
        else:
            self._surface.fill(FILL_BACKGROUND_COLOR)

        # Pipes
        for up_pipe, low_pipe in zip(self._upper_pipes, self._lower_pipes):
            self._surface.blit(self._images["pipe"][0], (up_pipe["x"], up_pipe["y"]))
            self._surface.blit(self._images["pipe"][1], (low_pipe["x"], low_pipe["y"]))

        # Base (ground)
        self._surface.blit(self._images["base"], (self._ground["x"], self._ground["y"]))

        # Getting player's rotation
        visible_rot = PLAYER_ROT_THR
        if self._player_rot <= PLAYER_ROT_THR:
            visible_rot = self._player_rot

        # Score
        # (must be drawn before the player, so the player overlaps it)
        if show_score:
            self._draw_score()

        # Player
        player_surface = pygame.transform.rotate(
            self._images["player"][self._player_idx],
            visible_rot,
        )
        player_surface_rect = player_surface.get_rect(
            topleft=(self._player_x, self._player_y)
        )
        self._surface.blit(player_surface, player_surface_rect)

    def _update_display(self) -> None:
        """Updates the display with the current surface of the renderer.

        A call to this method is usually preceded by a call to
        :meth:`.draw_surface()`. This method simply updates the display by
        showing the current state of the renderer's surface on it, it doesn't
        make any change to the surface.
        """
        if self._display is None:
            raise RuntimeError(
                "Tried to update the display, but a display hasn't been "
                "created yet! To create a display for the renderer, you must "
                "call the `make_display()` method."
            )

        pygame.event.get()
        self._display.blit(self._surface, [0, 0])
        pygame.display.update()

# %% [markdown]
# # Play the Environment

# %% [markdown]
# Randomly selecting actions

# %%
def play_random(render_mode="rgb_array"):
    env = FlappyBirdEnv(render_mode=render_mode)

    obs, _ = env.reset()
    done = False
    total_reward = 0

    frames = []

    # first frame
    frame = env.render()
    if frame is not None:
        frames.append(np.asarray(frame))

    while not done:
        # random action
        action = env.action_space.sample()

        # step
        obs, reward, terminated, truncated, info = env.step(action)
        total_reward += reward

        # render
        frame = env.render()
        if frame is not None:
            frames.append(np.asarray(frame))

        done = terminated or truncated

    print("Total reward:", total_reward)

    env.close()

    # save GIF
    gif_path = "flappy_random.gif"
    imageio.mimsave(gif_path, frames, fps=30)

    # show GIF
    display(Image(filename=gif_path))


if __name__ == "__main__":
    play_random()
# Out:
# Total reward: 0
# /usr/local/lib/python3.12/dist-packages/imageio/plugins/pillow.py:410: DeprecationWarning: The keyword `fps` is no longer supported. Use `duration`(in ms) instead, e.g. `fps=50` == `duration=20` (1000 * 1/50).
#   warnings.warn(

# %% [markdown]
# Manual Play

# %%
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display, clear_output
total_reward = 0
env = FlappyBirdEnv(render_mode="rgb_array")
obs, _ = env.reset()
done = False

out = widgets.Output()

flap_btn = widgets.Button(description="Flap")
next_btn = widgets.Button(description="Next")

def step(action):
    global obs, done, total_reward

    if done:
        return

    obs, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated

    with out:
        clear_output(wait=True)
        frame = env.render()
        plt.imshow(frame)
        plt.axis("off")
        plt.show()
        print("Observation:", obs)
        if (action == 1):
          print("Action: Flap")
        else:
          print("Action: Do nothing")

        if done:
            print("Game over")
            env.close()
        print("Step reward: ", reward)
        total_reward += reward
        print("Total reward: ", total_reward)


# Flap = action 1 + step
def on_flap_clicked(b):
    step(1)

# Next = action 0 + step
def on_next_clicked(b):
    step(0)

flap_btn.on_click(on_flap_clicked)
next_btn.on_click(on_next_clicked)

display(widgets.HBox([flap_btn, next_btn]))
display(out)

# first frame
with out:
    frame = env.render()
    plt.imshow(frame)
    plt.axis("off")
    plt.show()
    print("Observation:", obs)
# Out:
# HBox(children=(Button(description='Flap', style=ButtonStyle()), Button(description='Next', style=ButtonStyle()…
# Output()

# %% [markdown]
# # Train the Agent

# %%
import argparse
from pathlib import Path
from stable_baselines3 import DQN
from stable_baselines3.common.callbacks import BaseCallback

# --- Callback to record episode rewards during training ---
class RewardCallback(BaseCallback):
    def __init__(self):
        super().__init__()
        self.episode_rewards = []
        self._current_reward = 0.0

    def _on_step(self) -> bool:
        self._current_reward += self.locals["rewards"][0]
        if self.locals["dones"][0]:
            self.episode_rewards.append(self._current_reward)
            self._current_reward = 0.0
        return True

def train(timesteps, save_path) -> None:

    # 1) Create one training environment (no rendering during training).
    env = FlappyBirdEnv(render_mode=None)

    # 2) Create a DQN model with a simple MLP policy.
    model = DQN("MlpPolicy", env, verbose=1)

    # 3) Train for the requested number of timesteps.
    model.learn(total_timesteps=timesteps, callback=callback)

    # 4) Save the trained model.
    os.makedirs(os.path.dirname(save_path), exist_ok=True)
    model.save(str(save_path))
    print(f"Saved model to {save_path}.zip")

    env.close()

callback = RewardCallback()
save_path = "models/flappy_dqn"
timesteps = 1000000
train(timesteps, save_path)
# Out:
# Streaming output truncated to the last 5000 lines.
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00879  |
# |    n_updates        | 229450   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.7     |
# |    ep_rew_mean      | 4.5      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17228    |
# |    fps              | 751      |
# |    time_elapsed     | 1221     |
# |    total_timesteps  | 918116   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0178   |
# |    n_updates        | 229503   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.6     |
# |    ep_rew_mean      | 4.44     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17232    |
# |    fps              | 751      |
# |    time_elapsed     | 1221     |
# |    total_timesteps  | 918324   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0827   |
# |    n_updates        | 229555   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.5     |
# |    ep_rew_mean      | 4.36     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17236    |
# |    fps              | 751      |
# |    time_elapsed     | 1222     |
# |    total_timesteps  | 918524   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00286  |
# |    n_updates        | 229605   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.4     |
# |    ep_rew_mean      | 4.37     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17240    |
# |    fps              | 751      |
# |    time_elapsed     | 1222     |
# |    total_timesteps  | 918762   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00765  |
# |    n_updates        | 229665   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.6     |
# |    ep_rew_mean      | 4.37     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17244    |
# |    fps              | 751      |
# |    time_elapsed     | 1222     |
# |    total_timesteps  | 918998   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00516  |
# |    n_updates        | 229724   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.5     |
# |    ep_rew_mean      | 4.35     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17248    |
# |    fps              | 751      |
# |    time_elapsed     | 1222     |
# |    total_timesteps  | 919217   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.111    |
# |    n_updates        | 229779   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.6     |
# |    ep_rew_mean      | 4.37     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17252    |
# |    fps              | 751      |
# |    time_elapsed     | 1222     |
# |    total_timesteps  | 919433   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.023    |
# |    n_updates        | 229833   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 56.2     |
# |    ep_rew_mean      | 4.45     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17256    |
# |    fps              | 751      |
# |    time_elapsed     | 1223     |
# |    total_timesteps  | 919694   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0709   |
# |    n_updates        | 229898   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 56.4     |
# |    ep_rew_mean      | 4.56     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17260    |
# |    fps              | 751      |
# |    time_elapsed     | 1223     |
# |    total_timesteps  | 919933   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00406  |
# |    n_updates        | 229958   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57       |
# |    ep_rew_mean      | 4.65     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17264    |
# |    fps              | 751      |
# |    time_elapsed     | 1223     |
# |    total_timesteps  | 920194   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00918  |
# |    n_updates        | 230023   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57.6     |
# |    ep_rew_mean      | 4.72     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17268    |
# |    fps              | 751      |
# |    time_elapsed     | 1224     |
# |    total_timesteps  | 920486   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0437   |
# |    n_updates        | 230096   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57.6     |
# |    ep_rew_mean      | 4.71     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17272    |
# |    fps              | 751      |
# |    time_elapsed     | 1224     |
# |    total_timesteps  | 920714   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.023    |
# |    n_updates        | 230153   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.3     |
# |    ep_rew_mean      | 4.81     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17276    |
# |    fps              | 751      |
# |    time_elapsed     | 1224     |
# |    total_timesteps  | 920985   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0081   |
# |    n_updates        | 230221   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.1     |
# |    ep_rew_mean      | 4.81     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17280    |
# |    fps              | 752      |
# |    time_elapsed     | 1224     |
# |    total_timesteps  | 921195   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0077   |
# |    n_updates        | 230273   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57.5     |
# |    ep_rew_mean      | 4.63     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17284    |
# |    fps              | 751      |
# |    time_elapsed     | 1225     |
# |    total_timesteps  | 921405   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0184   |
# |    n_updates        | 230326   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.3     |
# |    ep_rew_mean      | 4.74     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17288    |
# |    fps              | 751      |
# |    time_elapsed     | 1225     |
# |    total_timesteps  | 921689   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0191   |
# |    n_updates        | 230397   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.4     |
# |    ep_rew_mean      | 4.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17292    |
# |    fps              | 751      |
# |    time_elapsed     | 1226     |
# |    total_timesteps  | 921914   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.058    |
# |    n_updates        | 230453   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.2     |
# |    ep_rew_mean      | 4.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17296    |
# |    fps              | 751      |
# |    time_elapsed     | 1226     |
# |    total_timesteps  | 922114   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.188    |
# |    n_updates        | 230503   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.2     |
# |    ep_rew_mean      | 4.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17300    |
# |    fps              | 751      |
# |    time_elapsed     | 1226     |
# |    total_timesteps  | 922328   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0144   |
# |    n_updates        | 230556   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.2     |
# |    ep_rew_mean      | 4.69     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17304    |
# |    fps              | 751      |
# |    time_elapsed     | 1226     |
# |    total_timesteps  | 922531   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00332  |
# |    n_updates        | 230607   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.2     |
# |    ep_rew_mean      | 4.67     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17308    |
# |    fps              | 751      |
# |    time_elapsed     | 1227     |
# |    total_timesteps  | 922767   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.011    |
# |    n_updates        | 230666   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57.7     |
# |    ep_rew_mean      | 4.61     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17312    |
# |    fps              | 751      |
# |    time_elapsed     | 1227     |
# |    total_timesteps  | 922972   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0117   |
# |    n_updates        | 230717   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57.5     |
# |    ep_rew_mean      | 4.58     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17316    |
# |    fps              | 751      |
# |    time_elapsed     | 1227     |
# |    total_timesteps  | 923215   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00513  |
# |    n_updates        | 230778   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57.5     |
# |    ep_rew_mean      | 4.6      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17320    |
# |    fps              | 751      |
# |    time_elapsed     | 1228     |
# |    total_timesteps  | 923430   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00248  |
# |    n_updates        | 230832   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57.9     |
# |    ep_rew_mean      | 4.64     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17324    |
# |    fps              | 751      |
# |    time_elapsed     | 1228     |
# |    total_timesteps  | 923692   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.119    |
# |    n_updates        | 230897   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57.9     |
# |    ep_rew_mean      | 4.64     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17328    |
# |    fps              | 751      |
# |    time_elapsed     | 1228     |
# |    total_timesteps  | 923901   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0121   |
# |    n_updates        | 230950   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.2     |
# |    ep_rew_mean      | 4.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17332    |
# |    fps              | 751      |
# |    time_elapsed     | 1229     |
# |    total_timesteps  | 924143   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00262  |
# |    n_updates        | 231010   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.5     |
# |    ep_rew_mean      | 4.86     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17336    |
# |    fps              | 751      |
# |    time_elapsed     | 1229     |
# |    total_timesteps  | 924379   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0259   |
# |    n_updates        | 231069   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.6     |
# |    ep_rew_mean      | 4.79     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17340    |
# |    fps              | 751      |
# |    time_elapsed     | 1229     |
# |    total_timesteps  | 924627   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.152    |
# |    n_updates        | 231131   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.6     |
# |    ep_rew_mean      | 4.81     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17344    |
# |    fps              | 751      |
# |    time_elapsed     | 1229     |
# |    total_timesteps  | 924854   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00859  |
# |    n_updates        | 231188   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.6     |
# |    ep_rew_mean      | 4.81     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17348    |
# |    fps              | 752      |
# |    time_elapsed     | 1230     |
# |    total_timesteps  | 925077   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00469  |
# |    n_updates        | 231244   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.8     |
# |    ep_rew_mean      | 4.84     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17352    |
# |    fps              | 752      |
# |    time_elapsed     | 1230     |
# |    total_timesteps  | 925314   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00977  |
# |    n_updates        | 231303   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.7     |
# |    ep_rew_mean      | 4.78     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17356    |
# |    fps              | 752      |
# |    time_elapsed     | 1230     |
# |    total_timesteps  | 925564   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0304   |
# |    n_updates        | 231365   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.7     |
# |    ep_rew_mean      | 4.78     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17360    |
# |    fps              | 752      |
# |    time_elapsed     | 1230     |
# |    total_timesteps  | 925806   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0325   |
# |    n_updates        | 231426   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.7     |
# |    ep_rew_mean      | 4.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17364    |
# |    fps              | 752      |
# |    time_elapsed     | 1231     |
# |    total_timesteps  | 926061   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0124   |
# |    n_updates        | 231490   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.4     |
# |    ep_rew_mean      | 4.74     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17368    |
# |    fps              | 752      |
# |    time_elapsed     | 1231     |
# |    total_timesteps  | 926329   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.109    |
# |    n_updates        | 231557   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.8     |
# |    ep_rew_mean      | 4.77     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17372    |
# |    fps              | 752      |
# |    time_elapsed     | 1231     |
# |    total_timesteps  | 926592   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0188   |
# |    n_updates        | 231622   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.4     |
# |    ep_rew_mean      | 4.73     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17376    |
# |    fps              | 752      |
# |    time_elapsed     | 1232     |
# |    total_timesteps  | 926829   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.15     |
# |    n_updates        | 231682   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.6     |
# |    ep_rew_mean      | 4.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17380    |
# |    fps              | 752      |
# |    time_elapsed     | 1232     |
# |    total_timesteps  | 927055   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0403   |
# |    n_updates        | 231738   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.7     |
# |    ep_rew_mean      | 4.87     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17384    |
# |    fps              | 752      |
# |    time_elapsed     | 1232     |
# |    total_timesteps  | 927274   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00561  |
# |    n_updates        | 231793   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.1     |
# |    ep_rew_mean      | 4.78     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17388    |
# |    fps              | 752      |
# |    time_elapsed     | 1232     |
# |    total_timesteps  | 927495   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00799  |
# |    n_updates        | 231848   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.1     |
# |    ep_rew_mean      | 4.69     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17392    |
# |    fps              | 752      |
# |    time_elapsed     | 1233     |
# |    total_timesteps  | 927722   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00704  |
# |    n_updates        | 231905   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.2     |
# |    ep_rew_mean      | 4.71     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17396    |
# |    fps              | 752      |
# |    time_elapsed     | 1233     |
# |    total_timesteps  | 927934   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0144   |
# |    n_updates        | 231958   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.4     |
# |    ep_rew_mean      | 4.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17400    |
# |    fps              | 752      |
# |    time_elapsed     | 1233     |
# |    total_timesteps  | 928170   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.148    |
# |    n_updates        | 232017   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.5     |
# |    ep_rew_mean      | 4.82     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17404    |
# |    fps              | 752      |
# |    time_elapsed     | 1233     |
# |    total_timesteps  | 928381   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0179   |
# |    n_updates        | 232070   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.2     |
# |    ep_rew_mean      | 4.78     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17408    |
# |    fps              | 752      |
# |    time_elapsed     | 1234     |
# |    total_timesteps  | 928585   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.085    |
# |    n_updates        | 232121   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.9     |
# |    ep_rew_mean      | 4.87     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17412    |
# |    fps              | 752      |
# |    time_elapsed     | 1234     |
# |    total_timesteps  | 928857   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0371   |
# |    n_updates        | 232189   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.4     |
# |    ep_rew_mean      | 4.8      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17416    |
# |    fps              | 752      |
# |    time_elapsed     | 1234     |
# |    total_timesteps  | 929057   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00785  |
# |    n_updates        | 232239   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.4     |
# |    ep_rew_mean      | 4.8      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17420    |
# |    fps              | 752      |
# |    time_elapsed     | 1234     |
# |    total_timesteps  | 929273   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00286  |
# |    n_updates        | 232293   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57.8     |
# |    ep_rew_mean      | 4.66     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17424    |
# |    fps              | 752      |
# |    time_elapsed     | 1235     |
# |    total_timesteps  | 929473   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00756  |
# |    n_updates        | 232343   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57.8     |
# |    ep_rew_mean      | 4.66     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17428    |
# |    fps              | 752      |
# |    time_elapsed     | 1235     |
# |    total_timesteps  | 929684   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00941  |
# |    n_updates        | 232395   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57.6     |
# |    ep_rew_mean      | 4.54     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17432    |
# |    fps              | 752      |
# |    time_elapsed     | 1235     |
# |    total_timesteps  | 929903   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0111   |
# |    n_updates        | 232450   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.1     |
# |    ep_rew_mean      | 4.59     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17436    |
# |    fps              | 752      |
# |    time_elapsed     | 1235     |
# |    total_timesteps  | 930185   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.112    |
# |    n_updates        | 232521   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57.9     |
# |    ep_rew_mean      | 4.64     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17440    |
# |    fps              | 752      |
# |    time_elapsed     | 1236     |
# |    total_timesteps  | 930412   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.149    |
# |    n_updates        | 232577   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57.9     |
# |    ep_rew_mean      | 4.65     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17444    |
# |    fps              | 752      |
# |    time_elapsed     | 1236     |
# |    total_timesteps  | 930648   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0264   |
# |    n_updates        | 232636   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.1     |
# |    ep_rew_mean      | 4.67     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17448    |
# |    fps              | 752      |
# |    time_elapsed     | 1236     |
# |    total_timesteps  | 930892   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0278   |
# |    n_updates        | 232697   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.3     |
# |    ep_rew_mean      | 4.69     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17452    |
# |    fps              | 752      |
# |    time_elapsed     | 1236     |
# |    total_timesteps  | 931142   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.018    |
# |    n_updates        | 232760   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57.9     |
# |    ep_rew_mean      | 4.67     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17456    |
# |    fps              | 752      |
# |    time_elapsed     | 1237     |
# |    total_timesteps  | 931351   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0115   |
# |    n_updates        | 232812   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57.6     |
# |    ep_rew_mean      | 4.65     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17460    |
# |    fps              | 752      |
# |    time_elapsed     | 1237     |
# |    total_timesteps  | 931569   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00266  |
# |    n_updates        | 232867   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57.1     |
# |    ep_rew_mean      | 4.58     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17464    |
# |    fps              | 752      |
# |    time_elapsed     | 1237     |
# |    total_timesteps  | 931769   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0362   |
# |    n_updates        | 232917   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57.2     |
# |    ep_rew_mean      | 4.58     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17468    |
# |    fps              | 752      |
# |    time_elapsed     | 1237     |
# |    total_timesteps  | 932047   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00466  |
# |    n_updates        | 232986   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 56.6     |
# |    ep_rew_mean      | 4.5      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17472    |
# |    fps              | 752      |
# |    time_elapsed     | 1238     |
# |    total_timesteps  | 932253   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00613  |
# |    n_updates        | 233038   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 56.3     |
# |    ep_rew_mean      | 4.45     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17476    |
# |    fps              | 752      |
# |    time_elapsed     | 1238     |
# |    total_timesteps  | 932457   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0378   |
# |    n_updates        | 233089   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 56.2     |
# |    ep_rew_mean      | 4.44     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17480    |
# |    fps              | 752      |
# |    time_elapsed     | 1238     |
# |    total_timesteps  | 932675   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00711  |
# |    n_updates        | 233143   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 56       |
# |    ep_rew_mean      | 4.43     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17484    |
# |    fps              | 752      |
# |    time_elapsed     | 1239     |
# |    total_timesteps  | 932877   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.12     |
# |    n_updates        | 233194   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.9     |
# |    ep_rew_mean      | 4.42     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17488    |
# |    fps              | 752      |
# |    time_elapsed     | 1239     |
# |    total_timesteps  | 933088   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0222   |
# |    n_updates        | 233246   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.7     |
# |    ep_rew_mean      | 4.47     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17492    |
# |    fps              | 752      |
# |    time_elapsed     | 1239     |
# |    total_timesteps  | 933288   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0499   |
# |    n_updates        | 233296   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.6     |
# |    ep_rew_mean      | 4.45     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17496    |
# |    fps              | 752      |
# |    time_elapsed     | 1240     |
# |    total_timesteps  | 933493   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0133   |
# |    n_updates        | 233348   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.6     |
# |    ep_rew_mean      | 4.45     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17500    |
# |    fps              | 752      |
# |    time_elapsed     | 1240     |
# |    total_timesteps  | 933729   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00505  |
# |    n_updates        | 233407   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.8     |
# |    ep_rew_mean      | 4.49     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17504    |
# |    fps              | 752      |
# |    time_elapsed     | 1240     |
# |    total_timesteps  | 933965   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00448  |
# |    n_updates        | 233466   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 56.3     |
# |    ep_rew_mean      | 4.54     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17508    |
# |    fps              | 752      |
# |    time_elapsed     | 1241     |
# |    total_timesteps  | 934217   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00843  |
# |    n_updates        | 233529   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.6     |
# |    ep_rew_mean      | 4.46     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17512    |
# |    fps              | 752      |
# |    time_elapsed     | 1241     |
# |    total_timesteps  | 934419   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0342   |
# |    n_updates        | 233579   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 56.1     |
# |    ep_rew_mean      | 4.52     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17516    |
# |    fps              | 752      |
# |    time_elapsed     | 1241     |
# |    total_timesteps  | 934670   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0048   |
# |    n_updates        | 233642   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 56       |
# |    ep_rew_mean      | 4.5      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17520    |
# |    fps              | 752      |
# |    time_elapsed     | 1241     |
# |    total_timesteps  | 934872   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00843  |
# |    n_updates        | 233692   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 56       |
# |    ep_rew_mean      | 4.55     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17524    |
# |    fps              | 752      |
# |    time_elapsed     | 1242     |
# |    total_timesteps  | 935069   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0318   |
# |    n_updates        | 233742   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.8     |
# |    ep_rew_mean      | 4.47     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17528    |
# |    fps              | 752      |
# |    time_elapsed     | 1242     |
# |    total_timesteps  | 935265   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0115   |
# |    n_updates        | 233791   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.6     |
# |    ep_rew_mean      | 4.55     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17532    |
# |    fps              | 752      |
# |    time_elapsed     | 1242     |
# |    total_timesteps  | 935468   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0056   |
# |    n_updates        | 233841   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.2     |
# |    ep_rew_mean      | 4.5      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17536    |
# |    fps              | 752      |
# |    time_elapsed     | 1242     |
# |    total_timesteps  | 935709   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0507   |
# |    n_updates        | 233902   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.3     |
# |    ep_rew_mean      | 4.5      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17540    |
# |    fps              | 752      |
# |    time_elapsed     | 1243     |
# |    total_timesteps  | 935940   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0221   |
# |    n_updates        | 233959   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55       |
# |    ep_rew_mean      | 4.48     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17544    |
# |    fps              | 752      |
# |    time_elapsed     | 1243     |
# |    total_timesteps  | 936153   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0471   |
# |    n_updates        | 234013   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.1     |
# |    ep_rew_mean      | 4.42     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17548    |
# |    fps              | 752      |
# |    time_elapsed     | 1243     |
# |    total_timesteps  | 936400   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00862  |
# |    n_updates        | 234074   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.2     |
# |    ep_rew_mean      | 4.45     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17552    |
# |    fps              | 752      |
# |    time_elapsed     | 1244     |
# |    total_timesteps  | 936665   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.131    |
# |    n_updates        | 234141   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.4     |
# |    ep_rew_mean      | 4.47     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17556    |
# |    fps              | 752      |
# |    time_elapsed     | 1244     |
# |    total_timesteps  | 936888   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00777  |
# |    n_updates        | 234196   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.3     |
# |    ep_rew_mean      | 4.45     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17560    |
# |    fps              | 752      |
# |    time_elapsed     | 1244     |
# |    total_timesteps  | 937097   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0228   |
# |    n_updates        | 234249   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.4     |
# |    ep_rew_mean      | 4.46     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17564    |
# |    fps              | 752      |
# |    time_elapsed     | 1244     |
# |    total_timesteps  | 937308   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0872   |
# |    n_updates        | 234301   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.7     |
# |    ep_rew_mean      | 4.37     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17568    |
# |    fps              | 752      |
# |    time_elapsed     | 1245     |
# |    total_timesteps  | 937514   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0228   |
# |    n_updates        | 234353   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.3     |
# |    ep_rew_mean      | 4.46     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17572    |
# |    fps              | 753      |
# |    time_elapsed     | 1245     |
# |    total_timesteps  | 937786   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.103    |
# |    n_updates        | 234421   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.9     |
# |    ep_rew_mean      | 4.53     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17576    |
# |    fps              | 753      |
# |    time_elapsed     | 1245     |
# |    total_timesteps  | 938043   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0432   |
# |    n_updates        | 234485   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.9     |
# |    ep_rew_mean      | 4.53     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17580    |
# |    fps              | 753      |
# |    time_elapsed     | 1245     |
# |    total_timesteps  | 938260   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0947   |
# |    n_updates        | 234539   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 56.3     |
# |    ep_rew_mean      | 4.56     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17584    |
# |    fps              | 753      |
# |    time_elapsed     | 1246     |
# |    total_timesteps  | 938507   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0201   |
# |    n_updates        | 234601   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 56.2     |
# |    ep_rew_mean      | 4.55     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17588    |
# |    fps              | 753      |
# |    time_elapsed     | 1246     |
# |    total_timesteps  | 938712   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00169  |
# |    n_updates        | 234652   |
# ----------------------------------
# ...
# |    total_timesteps  | 992476   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00579  |
# |    n_updates        | 248093   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 70.8     |
# |    ep_rew_mean      | 6.55     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18440    |
# |    fps              | 750      |
# |    time_elapsed     | 1322     |
# |    total_timesteps  | 992688   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0143   |
# |    n_updates        | 248146   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71       |
# |    ep_rew_mean      | 6.57     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18444    |
# |    fps              | 750      |
# |    time_elapsed     | 1322     |
# |    total_timesteps  | 992948   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.129    |
# |    n_updates        | 248211   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.1     |
# |    ep_rew_mean      | 6.58     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18448    |
# |    fps              | 750      |
# |    time_elapsed     | 1322     |
# |    total_timesteps  | 993184   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0104   |
# |    n_updates        | 248270   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.9     |
# |    ep_rew_mean      | 6.31     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18452    |
# |    fps              | 750      |
# |    time_elapsed     | 1323     |
# |    total_timesteps  | 993384   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00252  |
# |    n_updates        | 248320   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68       |
# |    ep_rew_mean      | 6.2      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18456    |
# |    fps              | 750      |
# |    time_elapsed     | 1323     |
# |    total_timesteps  | 993635   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0158   |
# |    n_updates        | 248383   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.4     |
# |    ep_rew_mean      | 6.26     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18460    |
# |    fps              | 750      |
# |    time_elapsed     | 1323     |
# |    total_timesteps  | 993907   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0125   |
# |    n_updates        | 248451   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.9     |
# |    ep_rew_mean      | 6.21     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18464    |
# |    fps              | 750      |
# |    time_elapsed     | 1324     |
# |    total_timesteps  | 994130   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0175   |
# |    n_updates        | 248507   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.6     |
# |    ep_rew_mean      | 6.17     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18468    |
# |    fps              | 750      |
# |    time_elapsed     | 1324     |
# |    total_timesteps  | 994419   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.125    |
# |    n_updates        | 248579   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.8     |
# |    ep_rew_mean      | 6.06     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18472    |
# |    fps              | 750      |
# |    time_elapsed     | 1324     |
# |    total_timesteps  | 994675   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0307   |
# |    n_updates        | 248643   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.2     |
# |    ep_rew_mean      | 6        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18476    |
# |    fps              | 750      |
# |    time_elapsed     | 1325     |
# |    total_timesteps  | 994889   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0182   |
# |    n_updates        | 248697   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.6     |
# |    ep_rew_mean      | 6.05     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18480    |
# |    fps              | 750      |
# |    time_elapsed     | 1325     |
# |    total_timesteps  | 995163   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0157   |
# |    n_updates        | 248765   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.2     |
# |    ep_rew_mean      | 6        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18484    |
# |    fps              | 750      |
# |    time_elapsed     | 1325     |
# |    total_timesteps  | 995399   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.13     |
# |    n_updates        | 248824   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 65.7     |
# |    ep_rew_mean      | 5.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18488    |
# |    fps              | 750      |
# |    time_elapsed     | 1326     |
# |    total_timesteps  | 995643   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0119   |
# |    n_updates        | 248885   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 64.6     |
# |    ep_rew_mean      | 5.79     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18492    |
# |    fps              | 750      |
# |    time_elapsed     | 1326     |
# |    total_timesteps  | 995855   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00746  |
# |    n_updates        | 248938   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 63.6     |
# |    ep_rew_mean      | 5.67     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18496    |
# |    fps              | 750      |
# |    time_elapsed     | 1326     |
# |    total_timesteps  | 996068   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00695  |
# |    n_updates        | 248991   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 63.2     |
# |    ep_rew_mean      | 5.61     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18500    |
# |    fps              | 750      |
# |    time_elapsed     | 1327     |
# |    total_timesteps  | 996315   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.135    |
# |    n_updates        | 249053   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 63.2     |
# |    ep_rew_mean      | 5.61     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18504    |
# |    fps              | 750      |
# |    time_elapsed     | 1327     |
# |    total_timesteps  | 996556   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0127   |
# |    n_updates        | 249113   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 62.5     |
# |    ep_rew_mean      | 5.51     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18508    |
# |    fps              | 750      |
# |    time_elapsed     | 1327     |
# |    total_timesteps  | 996798   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00621  |
# |    n_updates        | 249174   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 62.3     |
# |    ep_rew_mean      | 5.48     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18512    |
# |    fps              | 750      |
# |    time_elapsed     | 1328     |
# |    total_timesteps  | 997043   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.135    |
# |    n_updates        | 249235   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 62.6     |
# |    ep_rew_mean      | 5.52     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18516    |
# |    fps              | 750      |
# |    time_elapsed     | 1328     |
# |    total_timesteps  | 997301   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0206   |
# |    n_updates        | 249300   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 61.9     |
# |    ep_rew_mean      | 5.43     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18520    |
# |    fps              | 750      |
# |    time_elapsed     | 1328     |
# |    total_timesteps  | 997532   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0279   |
# |    n_updates        | 249357   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 61.3     |
# |    ep_rew_mean      | 5.36     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18524    |
# |    fps              | 750      |
# |    time_elapsed     | 1329     |
# |    total_timesteps  | 997766   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0436   |
# |    n_updates        | 249416   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 60.9     |
# |    ep_rew_mean      | 5.32     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18528    |
# |    fps              | 750      |
# |    time_elapsed     | 1329     |
# |    total_timesteps  | 998003   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0971   |
# |    n_updates        | 249475   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 61.3     |
# |    ep_rew_mean      | 5.36     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18532    |
# |    fps              | 750      |
# |    time_elapsed     | 1329     |
# |    total_timesteps  | 998333   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00405  |
# |    n_updates        | 249558   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 60.8     |
# |    ep_rew_mean      | 5.3      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18536    |
# |    fps              | 750      |
# |    time_elapsed     | 1330     |
# |    total_timesteps  | 998552   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0929   |
# |    n_updates        | 249612   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 61.2     |
# |    ep_rew_mean      | 5.35     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18540    |
# |    fps              | 750      |
# |    time_elapsed     | 1330     |
# |    total_timesteps  | 998804   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0224   |
# |    n_updates        | 249675   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 60.7     |
# |    ep_rew_mean      | 5.29     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18544    |
# |    fps              | 750      |
# |    time_elapsed     | 1330     |
# |    total_timesteps  | 999021   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0107   |
# |    n_updates        | 249730   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 60.6     |
# |    ep_rew_mean      | 5.26     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18548    |
# |    fps              | 750      |
# |    time_elapsed     | 1331     |
# |    total_timesteps  | 999241   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00303  |
# |    n_updates        | 249785   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 61.1     |
# |    ep_rew_mean      | 5.33     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18552    |
# |    fps              | 750      |
# |    time_elapsed     | 1331     |
# |    total_timesteps  | 999491   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00615  |
# |    n_updates        | 249847   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 61.3     |
# |    ep_rew_mean      | 5.35     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18556    |
# |    fps              | 750      |
# |    time_elapsed     | 1331     |
# |    total_timesteps  | 999763   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0162   |
# |    n_updates        | 249915   |
# ----------------------------------
# Saved model to models/flappy_dqn.zip

# %%
# --- Plot ---
rewards = np.array(callback.episode_rewards)
window = 20
smoothed = np.convolve(rewards, np.ones(window) / window, mode="valid")

fig, ax = plt.subplots(figsize=(6, 4))
ax.plot(rewards, alpha=0.3, color="steelblue", label="Episode reward")
ax.plot(range(window - 1, len(rewards)), smoothed, color="steelblue", linewidth=2, label=f"Smoothed)")
ax.axhline(0, color="gray", linestyle=":", linewidth=0.8)
ax.set_xlabel("Episode")
ax.set_ylabel("Total reward")
ax.set_title("DQN Training: FlappyBird")
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Evaluate the Agent

# %%
#!/usr/bin/env python3
"""Evaluate a trained Flappy Bird model."""

def run_stats(model: DQN, episodes: int, deterministic: bool) -> None:
    env = FlappyBirdEnv(render_mode=None)
    mean_reward, std_reward = evaluate_policy(
        model, env, n_eval_episodes=episodes, deterministic=deterministic
    )
    print(f"Episodes: {episodes}")
    print(f"Mean reward: {mean_reward:.2f}")
    print(f"Std reward: {std_reward:.2f}")
    env.close()


def run_rgb_array(
    model: DQN,
    episodes: int,
    deterministic: bool,
    gif_path: Path,
) -> None:
    """Evaluate with render_mode=rgb_array; save all episodes as one GIF."""
    env = FlappyBirdEnv(render_mode="rgb_array")
    all_frames: List[np.ndarray] = []

    for episode_idx in range(episodes):
        obs, _ = env.reset()
        terminated = False
        truncated = False
        total_reward = 0.0

        frame = env.render()
        if frame is not None:
            all_frames.append(np.asarray(frame))

        while not (terminated or truncated):
            action, _ = model.predict(obs, deterministic=deterministic)
            obs, reward, terminated, truncated, _ = env.step(action)
            total_reward += reward

            frame = env.render()
            if frame is not None:
                all_frames.append(np.asarray(frame))

        print(f"Episode {episode_idx + 1}/{episodes} reward: {total_reward:.2f}")

        # optional pause between episodes
        if frame is not None:
            last_frame = np.asarray(frame)
            for _ in range(10):
                all_frames.append(last_frame)

    env.close()

    if not all_frames:
        print("No frames captured; GIF not written.")
        return

    gif_path = Path(gif_path)
    gif_path.parent.mkdir(parents=True, exist_ok=True)

    h, w = all_frames[0].shape[0], all_frames[0].shape[1]
    fig, ax = plt.subplots(figsize=(w / 72, h / 72))
    ax.axis("off")
    im_artist = ax.imshow(all_frames[0])

    def _update(frame_idx: int):
        im_artist.set_array(all_frames[frame_idx])
        return (im_artist,)

    anim = animation.FuncAnimation(
        fig,
        _update,
        frames=len(all_frames),
        interval=1000 / 30,
        blit=False,
    )

    anim.save(str(gif_path), writer="pillow", fps=30)
    display(Image(filename=str(gif_path)))
    plt.close(fig)
    print(f"Saved all {episodes} episodes to {gif_path}")


def evaluate(model_path, mode, episodes, deterministic) -> None:
    model = DQN.load(str(model_path))
    gif_path = "flappy_evaluate.gif"

    if mode == "stats":
        run_stats(model, episodes, deterministic)
    elif mode == "rgb_array":
        run_rgb_array(
            model,
            episodes=episodes,
            deterministic=deterministic,
            gif_path=gif_path,
        )

# %% [markdown]
# Evaluation using Stats

# %%
model_path = "models/flappy_dqn"
mode = "stats"
episodes = 100
deterministic = False
evaluate(model_path, mode, episodes, deterministic)
# Out:
# Episodes: 100
# Mean reward: 2.66
# Std reward: 0.93

# %% [markdown]
# Evaluation using Simulation

# %%
model_path = "models/flappy_dqn"
mode = "rgb_array"
episodes = 1
deterministic = True
evaluate(model_path, mode, episodes, deterministic)
# Out:
# Episode 1/1 reward: 17.90
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Saved all 1 episodes to flappy_evaluate.gif
